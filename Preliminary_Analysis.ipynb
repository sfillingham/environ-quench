# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

# %%
centrals = pd.read_csv("data/hlist_1.00035_centralhalos.csv")
sats = pd.read_csv("data/hlist_1.00035_satellitehalos_2.0Rvir.csv")

# %%
clusters = centrals.iloc[np.where(centrals['mvir(10)'] > 5.e13)[0]]
dx = clusters['x(17)'] - sats['x(17)']
dy = clusters['y(18)'] - sats['y(18)']
dz = clusters['z(19)'] - sats['z(19)']

dist = np.sqrt(dx ** 2 + dy ** 2 + dz ** 2)
normdist

# %%
plt.figure(figsize=(8, 8))
plt.xlabel(r'$\rm Halo\ Mass\ (M_{vir})$')
sns.distplot(np.log10(centrals['mvir(10)']))
plt.show()

# %%
plt.figure(figsize=(8, 8))
plt.xlabel(r'$\rm Halo\ Mass\ (M_{vir})$')
sns.distplot(np.log10(sats['mvir(10)']))
plt.show()
